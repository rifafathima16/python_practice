# %%
balance = 10000
while True:
      print("\n1. Check Balance")
      print("2. Deposit")
      print("3. withdraw")
      print("4. Exit") 
      choice = int(input("Enter your choice: "))

      if choice == 1:
            print("balance =", balance)
      elif choice == 2:
            amount = int(input("Enterbamount:"))
      elif choice == 3:
            amount = int(input("Enter amount:"))
            if amount <= balance:
                balance = balance - amount
                print("New balance =", balance)
            else:
                print("Insufficiant balance")
      elif choice == 4:
           print("Thank you!")
           break
      else:
          print("Invalid choice")
# Out:
# 1. Check Balance
# 2. Deposit
# 3. withdraw
# 4. Exit
# New balance = 5500
#
# 1. Check Balance
# 2. Deposit
# 3. withdraw
# 4. Exit
